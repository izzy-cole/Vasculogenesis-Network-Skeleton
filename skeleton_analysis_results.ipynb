# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import networkx as nx
import tifffile as tiff

from pyvis.network import Network
from algorithms.analysis import register_skeleton_summary_data

# %%
summary_df = register_skeleton_summary_data()

# %%
import algorithms.database as database
import algorithms.analysis as analysis

summary_df=analysis.initialise_summary()
normal_set = database.get_embryo_IDs_from_condition()

normal_set = np.delete(normal_set, np.where(normal_set == 32))

titles = ["Number of Blood Island Clusters","Average Distance between Blood Island Clusters",
          "Average Blood Island Cluster Size","", 
          "Number of Enclosed Holes","Number of Disconnected Regions","",
          "","","","Proportion of Isolated Blood Island Clusters",""]

for i in range(len(summary_df.columns)):
    feature=summary_df.columns[i]
    title = titles[i]

    analysis.plot_feature_by_stage(feature, title, normal_set)

# %%
import algorithms.database as database
import algorithms.analysis as analysis

summary_df=analysis.initialise_summary()
live_set = database.get_embryo_IDs_from_drug("live")
print(live_set)

titles = ["Number of Blood Island Clusters","Average Distance between Blood Island Clusters",
          "Average Blood Island Cluster Size","", 
          "Number of Enclosed Holes","Number of Disconnected Regions","",
          "","","","Proportion of Isolated Blood Island Clusters",""]
for i in range(len(summary_df.columns)):
    feature=summary_df.columns[i]
    title = titles[i]
    analysis.plot_feature_by_condition(feature,title,embryo_ID_list=live_set)

# %%
from algorithms.network_type_analysis import degree_distribution_graph
import algorithms.database as database
import algorithms.analysis as analysis

import matplotlib.pyplot as plt

metadata_df = database.initialise_metadata()
embryo_ID_list = database.get_embryo_IDs_from_condition(stages=[4])
for i in embryo_ID_list:
    degree_distribution_graph(i)
plt.show()


embryo_ID_list = database.get_embryo_IDs_from_condition(stages=[9])
for i in embryo_ID_list:
    degree_distribution_graph(i)
plt.show()


embryo_ID_list = database.get_embryo_IDs_from_condition(stages=[13])
for i in embryo_ID_list:
    degree_distribution_graph(i)

# %%
import algorithms.database as database
import algorithms.analysis as analysis



analysis.plot_feature_by_condition("Number of Nodes", embryo_ID_list=[36,37,38,39])

# %%
import algorithms.network_type_analysis as network_type_analysis
import matplotlib.pyplot as plt
import algorithms.database as database
import algorithms.analysis as analysis


embryo_ID_list = database.get_embryo_IDs_from_condition(stages=[4,7,9,11,13])
for i in embryo_ID_list:
    network_type_analysis.clustering_graph(i)
    plt.show()

# %%
import algorithms.network_type_analysis as network_type_analysis
import matplotlib.pyplot as plt
import algorithms.database as database
import algorithms.analysis as analysis


embryo_ID_list = database.get_embryo_IDs_from_condition(stages=[4,7,9,11,13])
for i in embryo_ID_list:
    network_type_analysis.clustering_component_graph(i)
    plt.show()

# %%
import algorithms.network_type_analysis as network_type_analysis
import matplotlib.pyplot as plt
import algorithms.database as database
import algorithms.analysis as analysis

embryo_ID_list = database.get_embryo_IDs_from_condition(stages=[4,7,9,11,13])
for i in embryo_ID_list:
    network_type_analysis.edge_length_graph(i)
    plt.show()

# %%
import algorithms.network_type_analysis as network_type_analysis
import matplotlib.pyplot as plt
import algorithms.database as database
import algorithms.analysis as analysis

normal_set = database.get_embryo_IDs_from_condition()

embryo_ID_list = database.get_embryo_IDs_from_condition(stages=[4,7,9,11,13])
for i in embryo_ID_list:
    network_type_analysis.edge_whole_percentile_graph(i,normal_set)
    plt.show()
