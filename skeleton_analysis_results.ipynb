# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from algorithms.analysis import register_skeleton_summary_data

import algorithms.database as database
import algorithms.analysis as analysis
from config import results_path

#Set up more intuitive graph titles
titles = ["Number of Blood Island Clusters","Average Distance between Blood Island Clusters",
          "Average Blood Island Cluster Size","", 
          "Number of Enclosed Holes","Number of Disconnected Regions","",
          "","","","Proportion of Isolated Blood Island Clusters","Mean Edge Length, Relative to Embryo Width",
          "Number of Nodes per Square Micron","Basis Cycles per Square Micron","Isolated Nodes per Square Micron"]

# %% [markdown]
# # Display standard dataset embryo results

# %%
save=False

#Get the analytics data
summary_df=analysis.initialise_summary()

#Use "get_embryo_IDs_from_drug" to provide an array of embryo IDs of the dataset you want to view
#No arguments = normal set
normal_set = database.get_embryo_IDs_from_drug()

#Set up path to save results
save_path = results_path / "skeleton_analysis_results" / "main"

#Plot all of the features
for i in range(len(summary_df.columns)):
    feature=summary_df.columns[i]
    title = titles[i]
    if save:
        analysis.plot_feature_by_stage(feature, title, normal_set,save_path=save_path)
    else:
        analysis.plot_feature_by_stage(feature, title, normal_set)

# %% [markdown]
# # Display live imaging/timelapse dataset embryo results

# %%
save = False

summary_df=analysis.initialise_summary()
live_set = database.get_embryo_IDs_from_drug("live1")
print(live_set)

save_path = results_path / "skeleton_analysis_results" / "live_imaging"

for i in range(len(summary_df.columns)):
    feature=summary_df.columns[i]
    title = titles[i]
    if save:
        analysis.plot_feature_by_condition(feature,title,embryo_ID_list=live_set,save_path=save_path,live=True)
    else:
        analysis.plot_feature_by_condition(feature,title,embryo_ID_list=live_set,live=True)

# %% [markdown]
# # Display drug experiment dataset results

# %% [markdown]
# Set 1: 08/07/2026 MMP experiment: 3 controls, 1 10um, 2 20um, 3 50um

# %%
save=False
drug = "MMP"
date="20260708"

summary_df=analysis.initialise_summary()
drug_set = database.get_embryo_IDs_from_drug(drug,date=date)
print(drug_set)

save_path = results_path / "skeleton_analysis_results" / "drugs" / f"{drug}_{date}"

for i in range(len(summary_df.columns)):
    feature=summary_df.columns[i]
    title = titles[i]
    if save:
        analysis.plot_feature_by_condition(feature,title,embryo_ID_list=drug_set,condition_order=["control","10um","20um","50um"],save_path=save_path)
    else:
        analysis.plot_feature_by_condition(feature,title,embryo_ID_list=drug_set,condition_order=["control","10um","20um","50um"])

# %% [markdown]
# Set 2: 08/07/2026 CK666 experiment

# %%
save=False
drug = "CK666"
date = "20260708"

summary_df=analysis.initialise_summary()
drug_set = database.get_embryo_IDs_from_drug(drug,date=date)
print(drug_set)

save_path = results_path / "skeleton_analysis_results" / "drugs" / f"{drug}_{date}"

for i in range(len(summary_df.columns)):
    feature=summary_df.columns[i]
    title = titles[i]
    if save:
        analysis.plot_feature_by_condition(feature,title,embryo_ID_list=drug_set,condition_order=["control","50um","75um","100um"],save_path=save_path)
    else:
        analysis.plot_feature_by_condition(feature,title,embryo_ID_list=drug_set,condition_order=["control","50um","75um","100um"])

# %% [markdown]
# Set 3: 10/07/2026 4mu experiment

# %%
save = False
drug = "4mu"
date = "20260710"

summary_df=analysis.initialise_summary()
drug_set = database.get_embryo_IDs_from_drug(drug,date=date)
print(drug_set)

save_path = results_path / "skeleton_analysis_results" / "drugs" / f"{drug}_{date}"

for i in range(len(summary_df.columns)):
    feature=summary_df.columns[i]
    title = titles[i]
    if save:
        analysis.plot_feature_by_condition(feature,title,embryo_ID_list=drug_set,condition_order=["control","0-1","0-5","1"],save_path=save_path)
    else:
        analysis.plot_feature_by_condition(feature,title,embryo_ID_list=drug_set,condition_order=["control","0-1","0-5","1"])

# %%
save = False
drug = "dispace"
date = "20260710"

summary_df=analysis.initialise_summary()
drug_set = database.get_embryo_IDs_from_drug(drug,date=date,stages=[4])
print(drug_set)

save_path = results_path / "skeleton_analysis_results" / "drugs" / f"{drug}_{date}"

for i in range(len(summary_df.columns)):
    feature=summary_df.columns[i]
    title = titles[i]
    if save:
        analysis.plot_feature_by_condition(feature,title,embryo_ID_list=drug_set,condition_order=["control","0-1","0-5","1"],save_path=save_path)
    else:
        analysis.plot_feature_by_condition(feature,title,embryo_ID_list=drug_set,condition_order=["control","0-1","0-5","1"])

# %%
save = False
drug = "dispace"
date = "20260710"

summary_df=analysis.initialise_summary()
drug_set = database.get_embryo_IDs_from_drug(drug,date=date,stages=[8])
print(drug_set)

save_path = results_path / "skeleton_analysis_results" / "drugs" / f"{drug}_{date}"

for i in range(len(summary_df.columns)):
    feature=summary_df.columns[i]
    title = titles[i]
    if save:
        analysis.plot_feature_by_condition(feature,title,embryo_ID_list=drug_set,condition_order=["control","0-1","0-5","1"],save_path=save_path)
    else:
        analysis.plot_feature_by_condition(feature,title,embryo_ID_list=drug_set,condition_order=["control","0-1","0-5","1"])
