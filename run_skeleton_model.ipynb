# %%
print("Loading packages")
from skeleton_model import form_networks_all
import database

from config  import main_image_path,drugs_image_path
# Out:
# Loading packages

# %%
metadata_df = database.register_embryos_from_imageJ()
metadata_df = database.register_embryos_from_imageJ(drug="MMP",exp_date="20260304")
metadata_df = database.register_embryos_from_imageJ(drug="MMP",exp_date="20240719")
metadata_df = database.register_embryos_from_imageJ(drug="MMP",exp_date="20240803")
# Out:
# Successfully opened metadata file: C:\Users\isabe\Documents\work\systems bio\modelling vasculogenesis\python\data\imagej\imageJ_metadata.csv
# 29 embryos were skipped (already in database), 0 new embryos were appended. Total count: 29. Database saved.
# Error: cannot find metadata file: C:\Users\isabe\Documents\work\systems bio\modelling vasculogenesis\python\data\imagej\20260304_MMP_imageJ_metadata.csv
# Error: cannot find metadata file: C:\Users\isabe\Documents\work\systems bio\modelling vasculogenesis\python\data\imagej\20240719_MMP_imageJ_metadata.csv
# Error: cannot find metadata file: C:\Users\isabe\Documents\work\systems bio\modelling vasculogenesis\python\data\imagej\20240803_MMP_imageJ_metadata.csv

# %%
#base dataset
#form_networks_all(main_image_path)

#drug datasets
form_networks_all(main_image_path,skips=[[12,2,nan]])
form_networks_all(drugs_image_path / "20240719_MMP")
form_networks_all(drugs_image_path / "20240803_MMP")
form_networks_all(drugs_image_path / "20260304_MMP")
# Out:
# Existing file found for image HH10, n1 nan. Embryo ID: 19.
# Existing file found for image HH10, n2 nan. Embryo ID: 28.
# Existing file found for image HH10, n3 nan. Embryo ID: 20.
# Existing file found for image HH11, n1 nan. Embryo ID: 21.
# Existing file found for image HH11, n2 nan. Embryo ID: 22.
# Existing file found for image HH12, n1 nan. Embryo ID: 23.
# No existing file found for image HH12, n2 nan. Embryo ID: 29. Procesing now.
# Dimensions in pixels 3963x4012
# Dimensions in microns 15852.0x16048.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\isabe\.local\share\mamba\envs\networks\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2375
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 #base dataset
#       2 #form_networks_all(main_image_path)
#       3
#       4 #drug datasets
# ----> 5 form_networks_all(main_image_path,skips=[[12,2]])
#       6 form_networks_all(drugs_image_path / "20240719_MMP")
#       7 form_networks_all(drugs_image_path / "20240803_MMP")
#
# File c:\Users\isabe\Documents\work\systems bio\modelling vasculogenesis\python\skeleton\skeleton_model.py:240, in form_networks_all(path, skips)
#     237 print(f"Dimensions in microns {width*microns_per_pixel}x{height*microns_per_pixel}")
#     239 #set up node and edge matrices
# --> 240 nodes,adj = nodes_edges_from_image(skel,dists)
#     241 print(f"Unmerged length:{len(nodes)}")
#     243 #apply merging on nearby nodes
#
# File c:\Users\isabe\Documents\work\systems bio\modelling vasculogenesis\python\skeleton\skeleton_model.py:121, in nodes_edges_from_image(image, dists)
#     119                 type="endpt"
#     120                 nodes.loc[n] = {"x":x,"y":y,"type":type,"weight":weight}
# --> 121                 pix_neighbours.loc[n] = neighbours
#     122                 n+=1
#     125 #set up adjacency matrix
#
# File c:\Users\isabe\.local\share\mamba\envs\networks\Lib\site-packages\pandas\core\indexing.py:908, in _LocationIndexer.__setitem__(self, key, value)
#     906     maybe_callable = com.apply_if_callable(key, self.obj)
#     907     key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 908 indexer = self._get_setitem_indexer(key)
#     909 self._has_valid_setitem_indexer(key)
#     911 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File c:\Users\isabe\.local\share\mamba\envs\networks\Lib\site-packages\pandas\core\indexing.py:781, in _LocationIndexer._get_setitem_indexer(self, key)
#     777 if isinstance(key, range):
#     778     # GH#45479 test_loc_setitem_range_key
#     779     key = list(key)
# --> 781 return self._convert_to_indexer(key, axis=0)
#
# File c:\Users\isabe\.local\share\mamba\envs\networks\Lib\site-packages\pandas\core\indexing.py:1494, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1487 if is_scalar(key) or (
#    1488     isinstance(labels, MultiIndex) and is_hashable(key) and not contains_slice
#    1489 ):
#    1490     # Otherwise get_loc will raise InvalidIndexError
#    1491
#    1492     # if we are a label return me
#    1493     try:
# -> 1494         return labels.get_loc(key)
#    1495     except LookupError:
#    1496         if isinstance(key, tuple) and isinstance(labels, MultiIndex):
#
# File c:\Users\isabe\.local\share\mamba\envs\networks\Lib\site-packages\pandas\core\indexes\base.py:3815, in Index.get_loc(self, key)
#    3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#    3814     if isinstance(casted_key, slice) or (
# -> 3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
#    3819     raise KeyError(key) from err
#
# File c:\Users\isabe\.local\share\mamba\envs\networks\Lib\abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %%
summary_df = register_skeleton_summary_data()
