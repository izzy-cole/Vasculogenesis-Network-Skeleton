# %%
import tifffile as tiff
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from config import main_image_path
import os
import database
from area_analysis import normalised_area_graph

# %%
normal_set = database.get_embryo_IDs_from_condition()
normalised_area_graph(normal_set)
# Out:
# [[[372, 999], [373, 999], [372, 1000], [373, 1000], [373, 998], [374, 999], [374, 1000], [374, 998], [372, 1001], [373, 1001], [374, 1001], [373, 997], [374, 997], [375, 999], [375, 1000], [375, 998], [375, 1001], [375, 997], [373, 1002], [374, 1002], [375, 1002], [374, 996], [375, 996], [376, 999], [376, 1000], [376, 998], [376, 1001], [376, 997], [376, 1002], [376, 996], [373, 1003], [374, 1003], [375, 1003], [376, 1003], [374, 995], [375, 995], [376, 995], [377, 999], [377, 1000], [377, 998], [377, 1001], [377, 997], [377, 1002], [377, 996], [377, 1003], [377, 995], [374, 1004], [375, 1004], [376, 1004], [377, 1004], [376, 994], [377, 994], [378, 999], [378, 1000], [378, 998], [378, 1001], [378, 997], [378, 1002], [378, 996], [378, 1003], [378, 995], [378, 1004], [378, 994], [376, 1005], [377, 1005], [378, 1005], [377, 993], [378, 993], [379, 999], [379, 1000], [379, 998], [379, 1001], [379, 997], [379, 1002], [379, 996], [379, 1003], [379, 995], [379, 1004], [379, 994], [379, 993
# ...

# %%
stages_n = area_data.columns.get_level_values('Stage')
plt.scatter(stages_n, area_data.loc["Area"], alpha=0.7, edgecolors='black')
plt.xlabel("HH Stage")
plt.xticks(stages)
plt.ylabel("Area ($\\mu m^2$)")
