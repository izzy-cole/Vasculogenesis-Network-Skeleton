# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
# Add the root directory to Python's module search path
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

import tifffile as tiff
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import os


from config import main_image_path
import algorithms.database as database
from algorithms.area_analysis import normalised_area_graph,area_distribution_plot

# %%
normal_set = database.get_embryo_IDs_from_drug()
normalised_area_graph(normal_set)

# %%
metadata_df = database.initialise_metadata()
normal_set = database.get_embryo_IDs_from_drug()

metadata_filtered = metadata_df.loc[normal_set]

metadata_filtered["Embryo Area"] = (np.pi * metadata_filtered["Ellipse_W"]/2 *  metadata_filtered["Ellipse_H"]/2)
sns.lineplot(data=metadata_filtered, x="Stage",y="Embryo Area", linewidth=2.5)

plt.title("Embryo Area over Development")
plt.ylabel(f"Embryo Area in $\\mu m^2$")
plt.xlabel("HH Stage")

# %%
normal_set = database.get_embryo_IDs_from_condition()
for i in normal_set:
    area_distribution_plot(i)
