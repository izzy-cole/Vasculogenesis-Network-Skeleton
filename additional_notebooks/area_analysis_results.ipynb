# %%
import tifffile as tiff
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from config import main_image_path
import os
import database
from area_analysis import normalised_area_graph,area_distribution_plot

# %%
normal_set = database.get_embryo_IDs_from_condition()
normalised_area_graph(normal_set)

# %%
normal_set = database.get_embryo_IDs_from_condition()
for i in normal_set:
    area_distribution_plot(i)
